# %% [markdown]
# # LGM(LetsGrowMore) JUNE-2023
# # Task- 3  Exploratory Data Analysis on Dataset - Terrorism
# # Data Science Intern
# # Name- Shalini Pal

# %%
#import libraries
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
#read dataset
a = pd.read_csv('globalterrorismdb_0718dist.csv',encoding='ISO-8859-1')
a
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
# Top 5 rows
a.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
#Bottom 5 rows
a.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
# To check all columns
a.columns.to_list()
# Out:
# ['eventid',
#  'iyear',
#  'imonth',
#  'iday',
#  'approxdate',
#  'extended',
#  'resolution',
#  'country',
#  'country_txt',
#  'region',
#  'region_txt',
#  'provstate',
#  'city',
#  'latitude',
#  'longitude',
#  'specificity',
#  'vicinity',
#  'location',
#  'summary',
#  'crit1',
#  'crit2',
#  'crit3',
#  'doubtterr',
#  'alternative',
#  'alternative_txt',
#  'multiple',
#  'success',
#  'suicide',
#  'attacktype1',
#  'attacktype1_txt',
#  'attacktype2',
#  'attacktype2_txt',
#  'attacktype3',
#  'attacktype3_txt',
#  'targtype1',
#  'targtype1_txt',
#  'targsubtype1',
#  'targsubtype1_txt',
#  'corp1',
#  'target1',
#  'natlty1',
#  'natlty1_txt',
#  'targtype2',
#  'targtype2_txt',
#  'targsubtype2',
#  'targsubtype2_txt',
#  'corp2',
#  'target2',
#  'natlty2',
#  'natlty2_txt',
#  'targtype3',
#  'targtype3_txt',
#  'targsubtype3',
#  'targsubtype3_txt',
#  'corp3',
#  'target3',
#  'natlty3',
#  'natlty3_txt',
#  'gname',
#  'gsubname',
#  'gname2',
#  'gsubname2',
# ...

# %%
a.shape
# Out:
# (181691, 135)

# %%
a.describe(include='all')
# Out:
#              eventid          iyear         imonth           iday  \
# count   1.816910e+05  181691.000000  181691.000000  181691.000000
# unique           NaN            NaN            NaN            NaN
# top              NaN            NaN            NaN            NaN
# freq             NaN            NaN            NaN            NaN
# mean    2.002705e+11    2002.638997       6.467277      15.505644
# std     1.325957e+09      13.259430       3.388303       8.814045
# min     1.970000e+11    1970.000000       0.000000       0.000000
# 25%     1.991021e+11    1991.000000       4.000000       8.000000
# 50%     2.009022e+11    2009.000000       6.000000      15.000000
# 75%     2.014081e+11    2014.000000       9.000000      23.000000
# max     2.017123e+11    2017.000000      12.000000      31.000000
#
#                    approxdate       extended resolution        country  \
# count                    9239  181691.000000       2220  181691.000000
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %% [markdown]
# ### Check count of null values

# %%
for column, null_count in zip (a.columns, a.isnull().sum()):
    print(f"Column: {column}, Null Count: {null_count}")
# Out:
# Column: eventid, Null Count: 0
# Column: iyear, Null Count: 0
# Column: imonth, Null Count: 0
# Column: iday, Null Count: 0
# Column: approxdate, Null Count: 172452
# Column: extended, Null Count: 0
# Column: resolution, Null Count: 179471
# Column: country, Null Count: 0
# Column: country_txt, Null Count: 0
# Column: region, Null Count: 0
# Column: region_txt, Null Count: 0
# Column: provstate, Null Count: 421
# Column: city, Null Count: 434
# Column: latitude, Null Count: 4556
# Column: longitude, Null Count: 4557
# Column: specificity, Null Count: 6
# Column: vicinity, Null Count: 0
# Column: location, Null Count: 126196
# Column: summary, Null Count: 66129
# Column: crit1, Null Count: 0
# Column: crit2, Null Count: 0
# Column: crit3, Null Count: 0
# Column: doubtterr, Null Count: 1
# Column: alternative, Null Count: 152680
# Column: alternative_txt, Null Count: 152680
# Column: multiple, Null Count: 1
# Column: success, Null Count: 0
# Column: suicide, Null Count: 0
# ...

# %% [markdown]
# ### Check percentage of null values

# %%
for column, null_count in zip(a.columns, a.isnull().sum()/a.shape[0]*100):
    print(f"Column: {column}, Null Count: {null_count}")
# Out:
# Column: eventid, Null Count: 0.0
# Column: iyear, Null Count: 0.0
# Column: imonth, Null Count: 0.0
# Column: iday, Null Count: 0.0
# Column: approxdate, Null Count: 94.91499303762983
# Column: extended, Null Count: 0.0
# Column: resolution, Null Count: 98.77814531264619
# Column: country, Null Count: 0.0
# Column: country_txt, Null Count: 0.0
# Column: region, Null Count: 0.0
# Column: region_txt, Null Count: 0.0
# Column: provstate, Null Count: 0.23171208260177995
# Column: city, Null Count: 0.23886708752772565
# Column: latitude, Null Count: 2.507554034046816
# Column: longitude, Null Count: 2.5081044190411195
# Column: specificity, Null Count: 0.0033023099658210917
# Column: vicinity, Null Count: 0.0
# Column: location, Null Count: 69.45638474112641
# Column: summary, Null Count: 36.396409288297164
# Column: crit1, Null Count: 0.0
# Column: crit2, Null Count: 0.0
# Column: crit3, Null Count: 0.0
# Column: doubtterr, Null Count: 0.0005503849943035153
# ...

# %% [markdown]
# ### Drop unnecessary columns

# %%
m=a.drop(['approxdate', 'resolution', 'location', 'summary', 'alternative',
       'alternative_txt', 'attacktype2', 'attacktype2_txt', 'attacktype3',
       'attacktype3_txt', 'targtype2', 'targtype2_txt', 'targsubtype2',
       'targsubtype2_txt', 'corp2', 'target2', 'natlty2', 'natlty2_txt',
       'targtype3', 'targtype3_txt', 'targsubtype3', 'targsubtype3_txt',
       'corp3', 'target3', 'natlty3', 'natlty3_txt', 'gsubname', 'gname2',
       'gsubname2', 'gname3', 'gsubname3', 'motive', 'guncertain2',
       'guncertain3', 'nperps', 'nperpcap', 'claimed', 'claimmode',
       'claimmode_txt', 'claim2', 'claimmode2', 'claimmode2_txt', 'claim3',
       'claimmode3', 'claimmode3_txt', 'compclaim', 'weaptype2',
       'weaptype2_txt', 'weapsubtype2', 'weapsubtype2_txt', 'weaptype3',
       'weaptype3_txt', 'weapsubtype3', 'weapsubtype3_txt', 'weaptype4',
       'weaptype4_txt', 'weapsubtype4', 'weapsubtype4_txt', 'weapdetail',
       'nkillus', 'nkillter', 'nwoundus', 'nwoundte', 'propextent',
       'propextent_txt', 'propvalue', 'propcomment', 'nhostkid', 'nhostkidus',
       'nhours', 'ndays', 'divert', 'kidhijcountry', 'ransom', 'ransomamt',
       'ransomamtus', 'ransompaid', 'ransompaidus', 'ransomnote',
       'hostkidoutcome', 'hostkidoutcome_txt', 'nreleased', 'addnotes',
       'scite1', 'scite2', 'scite3', 'related','extended', 'resolution', 'country','region', 'vicinity', 'crit1','crit2','crit3',
         'doubtterr', 'alternative','alternative_txt','attacktype1','targtype1','targsubtype1', 'targsubtype1_txt','corp1', 
          'target1',
         'guncertain1','individual','weaptype1', 'weapsubtype1','weapsubtype1_txt', 'nkillus', 'nkillter','nwoundus',
          'nwoundte', 'property','natlty1','natlty1_txt',
         'ishostkid','dbsource', 'INT_LOG', 'INT_IDEO', 'INT_MISC','INT_ANY' ], axis = 1)

# %% [markdown]
# ### After drop check data shape

# %%
m.shape
# Out:
# (181691, 20)

# %% [markdown]
# ### Check missing value

# %%
m.isnull().sum()
# Out:
# eventid                0
# iyear                  0
# imonth                 0
# iday                   0
# country_txt            0
# region_txt             0
# provstate            421
# city                 434
# latitude            4556
# longitude           4557
# specificity            6
# multiple               1
# success                0
# suicide                0
# attacktype1_txt        0
# targtype1_txt          0
# gname                  0
# weaptype1_txt          0
# nkill              10313
# nwound             16311
# dtype: int64

# %% [markdown]
# ### Handle missing values

# %%
k=m.dropna()
k
# Out:
#              eventid  iyear  imonth  iday    country_txt  \
# 1       197000000002   1970       0     0         Mexico
# 2       197001000001   1970       1     0    Philippines
# 5       197001010002   1970       1     1  United States
# 6       197001020001   1970       1     2        Uruguay
# 7       197001020002   1970       1     2  United States
# ...              ...    ...     ...   ...            ...
# 181686  201712310022   2017      12    31        Somalia
# 181687  201712310029   2017      12    31          Syria
# 181688  201712310030   2017      12    31    Philippines
# 181689  201712310031   2017      12    31          India
# 181690  201712310032   2017      12    31    Philippines
#
#                         region_txt        provstate           city   latitude  \
# 1                    North America          Federal    Mexico city  19.371887
# 2                   Southeast Asia           Tarlac        Unknown  15.478598
# ...

# %%
k.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# country_txt        0
# region_txt         0
# provstate          0
# city               0
# latitude           0
# longitude          0
# specificity        0
# multiple           0
# success            0
# suicide            0
# attacktype1_txt    0
# targtype1_txt      0
# gname              0
# weaptype1_txt      0
# nkill              0
# nwound             0
# dtype: int64

# %% [markdown]
# ### Rename columns

# %%
k.rename(columns ={'eventid': 'event_id','iyear':'year','imonth':'month','iday':'day','nkill':'death','weaptype1_txt':'weapon',
                   'targtype1_txt':'target','attacktype1_txt':'attack_type','provstate':'state','region_txt' :'region','country_txt':
                   'country','nwound':'wound','gname':'group_name'}, inplace=True)

# %%
k
# Out:
#             event_id  year  month  day        country  \
# 1       197000000002  1970      0    0         Mexico
# 2       197001000001  1970      1    0    Philippines
# 5       197001010002  1970      1    1  United States
# 6       197001020001  1970      1    2        Uruguay
# 7       197001020002  1970      1    2  United States
# ...              ...   ...    ...  ...            ...
# 181686  201712310022  2017     12   31        Somalia
# 181687  201712310029  2017     12   31          Syria
# 181688  201712310030  2017     12   31    Philippines
# 181689  201712310031  2017     12   31          India
# 181690  201712310032  2017     12   31    Philippines
#
#                             region            state           city   latitude  \
# 1                    North America          Federal    Mexico city  19.371887
# 2                   Southeast Asia           Tarlac        Unknown  15.478598
# 5                    North America         Illinois          Cairo  37.005105
# ...

# %% [markdown]
# ### Check unique value in each columns

# %%
for column, null_count in zip (k.columns, k.nunique()):
    print(f"Column: {column}, unique Count: {null_count}")
# Out:
# Column: event_id, unique Count: 160110
# Column: year, unique Count: 47
# Column: month, unique Count: 13
# Column: day, unique Count: 32
# Column: country, unique Count: 202
# Column: region, unique Count: 12
# Column: state, unique Count: 2768
# Column: city, unique Count: 32394
# Column: latitude, unique Count: 44602
# Column: longitude, unique Count: 44329
# Column: specificity, unique Count: 4
# Column: multiple, unique Count: 2
# Column: success, unique Count: 2
# Column: suicide, unique Count: 2
# Column: attack_type, unique Count: 9
# Column: target, unique Count: 22
# Column: group_name, unique Count: 3292
# Column: weapon, unique Count: 12
# Column: death, unique Count: 179
# Column: wound, unique Count: 238

# %% [markdown]
# ### Number of death in each country

# %%
death = k.groupby('country')['death'].sum().reset_index()
country_death= country_killings.sort_values(by='death', ascending=False)
country_death
# Out:
#          country    death
# 81          Iraq  67997.0
# 0    Afghanistan  35643.0
# 131     Pakistan  22389.0
# 77         India  17580.0
# 164    Sri Lanka  13843.0
# ..           ...      ...
# 76       Iceland      0.0
# 161  South Yemen      0.0
# 22        Brunei      0.0
# 150   Seychelles      0.0
# 101   Luxembourg      0.0
#
# [202 rows x 2 columns]

# %% [markdown]
# # top 5 country where most death occurs- Iraq,Afghanistan,Pakistan,India,Sri Lanka

# %%
highest_death_country = country_death.iloc[0]['country']
print(f"The country with the highest number of killings is: {highest_death_country}")
# Out:
# The country with the highest number of killings is: Iraq

# %% [markdown]
# ### In which reagion more death occured

# %%
death_region=k.groupby('region')['death'].sum().sort_values(ascending=False)

death_region
# Out:
# region
# Middle East & North Africa     113415.0
# South Asia                      91859.0
# Sub-Saharan Africa              53402.0
# South America                   24585.0
# Central America & Caribbean     22255.0
# Southeast Asia                  12343.0
# Eastern Europe                   6179.0
# North America                    4849.0
# Western Europe                   4592.0
# East Asia                         818.0
# Central Asia                      800.0
# Australasia & Oceania             144.0
# Name: death, dtype: float64

# %%
middle_east_north_africa = k[k['region'] == 'Middle East & North Africa']
countries_in_region = middle_east_north_africa['country'].unique()

print("Countries in the Middle East & North Africa region:")
for country in countries_in_region:
    print(country)
# Out:
# Countries in the Middle East & North Africa region:
# Egypt
# Lebanon
# Jordan
# Turkey
# Iran
# South Yemen
# Israel
# West Bank and Gaza Strip
# Algeria
# Morocco
# Kuwait
# North Yemen
# Syria
# United Arab Emirates
# Iraq
# Tunisia
# Libya
# Saudi Arabia
# Bahrain
# Qatar
# Yemen
# Western Sahara
# International

# %%
middle_east_north_africa = k[k['region'] == 'Middle East & North Africa']
country_attacks = middle_east_north_africa['country'].value_counts()
country_with_most_attacks = country_attacks.index[0:5]

print(f"The country in the Middle East & North Africa region with the highest number of attacks is: {country_with_most_attacks}")
# Out:
# The country in the Middle East & North Africa region with the highest number of attacks is: Index(['Iraq', 'Turkey', 'Yemen', 'Algeria', 'Egypt'], dtype='object')

# %% [markdown]
# ### In which country more wound case

# %%
n=k.groupby('country')['wound'].sum().sort_values(ascending=False)
n
# Out:
# country
# Iraq               134093.0
# Afghanistan         43881.0
# Pakistan            41674.0
# India               28500.0
# United States       20697.0
#                      ...
# Solomon Islands         0.0
# Vanuatu                 0.0
# South Vietnam           0.0
# South Yemen             0.0
# Iceland                 0.0
# Name: wound, Length: 202, dtype: float64

# %% [markdown]
# ### Percentage of attack type

# %%
k['attack_type'].value_counts()/k.shape[0]*100
# Out:
# Bombing/Explosion                      50.617076
# Armed Assault                          22.885516
# Assassination                          10.857535
# Facility/Infrastructure Attack          5.907189
# Hostage Taking (Kidnapping)             4.736119
# Unknown                                 3.599400
# Unarmed Assault                         0.552120
# Hostage Taking (Barricade Incident)     0.502779
# Hijacking                               0.342265
# Name: attack_type, dtype: float64

# %% [markdown]
# ## Visulizing the data

# %%
sns.histplot(k['attack_type'])
plt.title('Attack types')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### Bombing/Explosion   is major type of attack

# %% [markdown]
# ### top 5 attack type

# %%
k['attack_type'].value_counts()[:5].plot.pie(autopct='%1.1f%%')
plt.show()

# %%
k['weapon'].value_counts()[:5].plot.pie(autopct='%1.1f%%')
plt.show()

# %% [markdown]
# ### Number of Death pr year

# %%
plt.figure(figsize=(13, 6))
k.groupby(['year'])['death'].sum().plot(kind='bar')
plt.ylabel('number of death')
plt.title("number of death occur in years",fontsize=20)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(13, 6))
k.groupby(['year'])['wound'].sum().plot(kind='bar')
plt.ylabel('number of wound')
plt.title("number of wound occur in years",fontsize=20)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### in 2015 most death happened

# %%
nyear=k.year.value_counts()
rate=(nyear[2017]-nyear[1970])/nyear[2017]*100
print(f'attack happened in 1970,{nyear[1970]} and attack happened in 2017 {nyear[2017]}' )
print(f'number of attack increased,{rate}')
# Out:
# attack happened in 1970,589 and attack happened in 2017 9833
# number of attack increased,94.00996643954032

# %% [markdown]
# ### number of death in each region

# %%
plt.figure(figsize=(13, 6))
sns.countplot(x='region',data=k, palette='inferno',order=k['region'].value_counts().index)
plt.xlabel('region')
plt.title("Number of Deaths Occur in region", fontsize=20)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### Check which terrorist group more acctive

# %%
sns.barplot(y=k['group_name'].value_counts()[1:25].index,x=k['group_name'].value_counts()[1:25],palette='magma')
plt.show()

# %%
k['group_name'].value_counts()
# Out:
# Unknown                                                    76418
# Taliban                                                     6792
# Islamic State of Iraq and the Levant (ISIL)                 4704
# Shining Path (SL)                                           3779
# New People's Army (NPA)                                     2394
#                                                            ...
# Anti-Racist Guerrilla Nuclei                                   1
# Anti-Imperialist Commando                                      1
# Association of Mobil Spill Affected Communities (AMSAC)        1
# New Revolutionary Alternative (NRA)                            1
# Revolutionary Bolivariano Movement 200                         1
# Name: group_name, Length: 3292, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x=k['target'].value_counts().index,y=k['target'].value_counts().values,palette='icefire')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # Insight derive from above dataset
# ### Most attack country- Iraq
# ### Top 5 most attacked country-Iraq, Afghanistan, Pakistan, India, Sri Lanka
# ### Most death and wound occured -Iraq
# ### Most target - Private Citizens and Property
# ### Most used attack type -Bombing/Explosion
# ### Most active organization-Taliban
# ### Most used weapon- Explosives
# ### Mostly deaths happened in -2016
# ### Mostly people wounded in -2015
# ### Mostly affected region-Middle east and North Africa
